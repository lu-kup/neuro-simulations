# %%
import neuron_model

print(neuron_model.model)
print(neuron_model.neuron)
# Out:
# HT
# ML

# %%
import numpy as np
from scipy.integrate import solve_ivp
import bifurcation_finder
import matplotlib.pyplot as plt

# %%
ts = np.linspace(0, neuron_model.T, 10**5)

# %%
neuron_model.I_app = 20
neuron_model.I_spike = 20

V_sol = bifurcation_finder.steady_state_V(neuron_model.I_app, -80)
print(V_sol)
w_sol = neuron_model.w_inf(V_sol)
print(w_sol)

V_sol_unst = bifurcation_finder.steady_state_V(neuron_model.I_app, -40)
print(V_sol_unst)
w_sol_unst = neuron_model.w_inf(V_sol_unst)
print(w_sol_unst)

ax1, ax2 = neuron_model.visualise_phase_lines(ts, (0,0,0.4), [[-43.5, 0.025],[-40, 0.025], [-20,0.2], [20,0.7], [-40,0.35], [-20,-0.1]], interval=400, annotation=True)
#ax1 = neuron_model.visualise_phase_lines(ts, 'black', [[-50, 0]], interval=400, annotation=True)
ax1.plot([V_sol], [w_sol], marker='o', markerfacecolor='black', markeredgecolor='black',zorder=10,markersize=10)
ax1.plot([V_sol_unst], [w_sol_unst], marker='o', markerfacecolor='white', markeredgecolor='black',zorder=10,markersize=10)
ax2.remove()
ax1.set_title("I_app = 20")
plt.show()
# Out:
# -68.64061889869545
# 0.00016193982656675932
# -43.24568234965487
# 0.02535403335266606
# ...

# %%
neuron_model.I_app = 35
neuron_model.I_spike = 35

V_sol = bifurcation_finder.steady_state_V(neuron_model.I_app, -80)
print(V_sol)
w_sol = neuron_model.w_inf(V_sol)
print(w_sol)

V_sol_unst = bifurcation_finder.steady_state_V(neuron_model.I_app, -40)
print(V_sol_unst)
w_sol_unst = neuron_model.w_inf(V_sol_unst)
print(w_sol_unst)

ax1, ax2 = neuron_model.visualise_phase_lines(ts, (0,0,0.4), [[-50, 0],[-47, 0.01], [-20,0.2], [20,0.7], [-40,0.35], [-20,-0.1]], interval=400, annotation=True)
#ax1 = neuron_model.visualise_phase_lines(ts, 'black', [[-50, 0]], interval=400, annotation=True)
ax1.plot([V_sol], [w_sol], marker='o', markerfacecolor='black', markeredgecolor='black',zorder=10,markersize=10)
ax1.plot([V_sol_unst], [w_sol_unst], marker='o', markerfacecolor='white', markeredgecolor='black',zorder=10,markersize=10)
ax2.remove()
ax1.set_title("I_app = 35")

plt.show()
# Out:
# -64.04938315117111
# 0.00040554356453798013
# -47.933825571996834
# 0.010083051398203202
# ...

# %%
neuron_model.I_app = 46.30713070328974
neuron_model.I_spike = 46.30713070328974

V_sol = bifurcation_finder.steady_state_V(neuron_model.I_app, -80)
print(V_sol)
w_sol = neuron_model.w_inf(V_sol)
print(w_sol)

V_sol_unst = bifurcation_finder.steady_state_V(neuron_model.I_app, -40)
print(V_sol_unst)
w_sol_unst = neuron_model.w_inf(V_sol_unst)
print(w_sol_unst)

ax1, ax2 = neuron_model.visualise_phase_lines(ts, (0,0,0.4), [[-53, 0], [-20,0.2], [20,0.7], [-40,0.35], [-20,-0.1]], interval=400, annotation=True)
#ax1 = neuron_model.visualise_phase_lines(ts, 'black', [[-50, 0]], interval=400, annotation=True)
ax1.plot([V_sol], [w_sol], marker='o', fillstyle='left', markerfacecolor='black', markeredgecolor='black',zorder=10,markersize=10)
ax2.remove()
ax1.set_title("I_app = 46.3071")

plt.show()
# Out:
# -55.883008003706685
# 0.0020731690057092522
# -55.88299373309573
# 0.0020731749105282193
# ...

# %%
neuron_model.I_app = 60
neuron_model.I_spike = 60

ax1, ax2 = neuron_model.visualise_phase_lines(ts, (0,0,0.4), [[-20,0.2], [20,0.7], [-40,0.35], [-20,-0.1]], interval=400, annotation=False)
#ax1 = neuron_model.visualise_phase_lines(ts, 'black', [[-50, 0]], interval=400, annotation=True)
ax2.remove()
ax1.set_title("I_app = 60")

plt.show()

# %%
import bifurcation_finder

neuron_model.I_app = 20
neuron_model.I_spike = 20

V_sol = bifurcation_finder.steady_state_V(neuron_model.I_app, -80)
print(V_sol)
w_sol = neuron_model.w_inf(V_sol)
print(w_sol)

V_sol_unst = bifurcation_finder.steady_state_V(neuron_model.I_app, -50)
print(V_sol)
w_sol_unst = neuron_model.w_inf(V_sol)
print(w_sol)
# Out:
# -68.64061889869545
# 0.00016193982656675932
# -68.64061889869545
# 0.00016193982656675932

# %% [markdown]
# SINGLE TRAJECTORIES

# %%
neuron_model.I_app = 20
neuron_model.I_spike = 20

V_sol = bifurcation_finder.steady_state_V(neuron_model.I_app, -80)
print(V_sol)
w_sol = neuron_model.w_inf(V_sol)
print(w_sol)

V_sol_unst = bifurcation_finder.steady_state_V(neuron_model.I_app, -40)
print(V_sol_unst)
w_sol_unst = neuron_model.w_inf(V_sol_unst)
print(w_sol_unst)

ax1, ax2 = neuron_model.visualise_phase_lines(ts, (0,0,0.4), [[-46, 0]], interval=400, annotation=True)
#ax1 = neuron_model.visualise_phase_lines(ts, 'black', [[-50, 0]], interval=400, annotation=True)
ax1.plot([V_sol], [w_sol], marker='o', markerfacecolor='black', markeredgecolor='black',zorder=10,markersize=10)
ax1.plot([V_sol_unst], [w_sol_unst], marker='o', markerfacecolor='white', markeredgecolor='black',zorder=10,markersize=10)
ax1.set_title(f"I_app = {neuron_model.I_app}")

plt.show()
# Out:
# -68.64061889869545
# 0.00016193982656675932
# -43.24568234965487
# 0.02535403335266606
# ...

# %%
neuron_model.I_app = 20
neuron_model.I_spike = 20

V_sol = bifurcation_finder.steady_state_V(neuron_model.I_app, -80)
print(V_sol)
w_sol = neuron_model.w_inf(V_sol)
print(w_sol)

V_sol_unst = bifurcation_finder.steady_state_V(neuron_model.I_app, -40)
print(V_sol_unst)
w_sol_unst = neuron_model.w_inf(V_sol_unst)
print(w_sol_unst)

ax1, ax2 = neuron_model.visualise_phase_lines(ts, (0,0,0.4), [[-42, 0]], interval=400, annotation=True)
#ax1 = neuron_model.visualise_phase_lines(ts, 'black', [[-50, 0]], interval=400, annotation=True)
ax1.plot([V_sol], [w_sol], marker='o', markerfacecolor='black', markeredgecolor='black',zorder=10,markersize=10)
ax1.plot([V_sol_unst], [w_sol_unst], marker='o', markerfacecolor='white', markeredgecolor='black',zorder=10,markersize=10)
ax1.set_title(f"I_app = {neuron_model.I_app}")

plt.show()
# Out:
# -68.64061889869545
# 0.00016193982656675932
# -43.24568234965487
# 0.02535403335266606
# ...

# %%
neuron_model.I_app = 46.30713070328974
neuron_model.I_spike = 46.30713070328974

V_sol = bifurcation_finder.steady_state_V(neuron_model.I_app, -80)
print(V_sol)
w_sol = neuron_model.w_inf(V_sol)
print(w_sol)

ax1, ax2 = neuron_model.visualise_phase_lines(ts, (0,0,0.4), [[-53, 0]], interval=400, annotation=True)
#ax1 = neuron_model.visualise_phase_lines(ts, 'black', [[-50, 0]], interval=400, annotation=True)
ax1.plot([V_sol], [w_sol], marker='o', fillstyle='left', markerfacecolor='black', markeredgecolor='black',zorder=10,markersize=10)
ax1.set_title(f"I_app = 46.3071")

plt.show()
# Out:
# -55.883008003706685
# 0.0020731690057092522
# ...

# %%
neuron_model.I_app = 60
neuron_model.I_spike = 60

ax1, ax2 = neuron_model.visualise_phase_lines(ts, (0,0,0.4), [[-20, 0]], interval=400, annotation=False)
#ax1 = neuron_model.visualise_phase_lines(ts, 'black', [[-50, 0]], interval=400, annotation=True)
ax1.set_title("I_app = 60")

plt.show()

# %%
neuron_model.I_app = 20
neuron_model.I_spike = 20

V_sol = bifurcation_finder.steady_state_V(neuron_model.I_app, -80)
print(V_sol)
w_sol = neuron_model.w_inf(V_sol)
print(w_sol)

V_sol_unst = bifurcation_finder.steady_state_V(neuron_model.I_app, -40)
print(V_sol_unst)
w_sol_unst = neuron_model.w_inf(V_sol_unst)
print(w_sol_unst)

ax1, ax2 = neuron_model.visualise_phase_lines(ts, (0,0,0.4), [[-47, 0]], interval=400, annotation=True)
#ax1 = neuron_model.visualise_phase_lines(ts, 'black', [[-50, 0]], interval=400, annotation=True)
ax1.plot([V_sol], [w_sol], marker='o', markerfacecolor='black', markeredgecolor='black',zorder=10,markersize=10)
ax1.plot([V_sol_unst], [w_sol_unst], marker='o', markerfacecolor='white', markeredgecolor='black',zorder=10,markersize=10)
ax1.set_title(f"V_0 = -47")

plt.show()
# Out:
# -68.64061889869545
# 0.00016193982656675932
# -43.24568234965487
# 0.02535403335266606
# ...

# %%
neuron_model.I_app = 20
neuron_model.I_spike = 20

V_sol = bifurcation_finder.steady_state_V(neuron_model.I_app, -80)
print(V_sol)
w_sol = neuron_model.w_inf(V_sol)
print(w_sol)

V_sol_unst = bifurcation_finder.steady_state_V(neuron_model.I_app, -40)
print(V_sol_unst)
w_sol_unst = neuron_model.w_inf(V_sol_unst)
print(w_sol_unst)

ax1, ax2 = neuron_model.visualise_phase_lines(ts, (0,0,0.4), [[-42, 0]], interval=400, annotation=True)
#ax1 = neuron_model.visualise_phase_lines(ts, 'black', [[-50, 0]], interval=400, annotation=True)
ax1.plot([V_sol], [w_sol], marker='o', markerfacecolor='black', markeredgecolor='black',zorder=10,markersize=10)
ax1.plot([V_sol_unst], [w_sol_unst], marker='o', markerfacecolor='white', markeredgecolor='black',zorder=10,markersize=10)
ax1.set_title(f"V_0 = -42")

plt.show()
# Out:
# -68.64061889869545
# 0.00016193982656675932
# -43.24568234965487
# 0.02535403335266606
# ...

# %%
neuron_model.I_app = 20
neuron_model.I_spike = 20

V_sol = bifurcation_finder.steady_state_V(neuron_model.I_app, -80)
print(V_sol)
w_sol = neuron_model.w_inf(V_sol)
print(w_sol)

V_sol_unst = bifurcation_finder.steady_state_V(neuron_model.I_app, -40)
print(V_sol_unst)
w_sol_unst = neuron_model.w_inf(V_sol_unst)
print(w_sol_unst)

ax1, ax2 = neuron_model.visualise_phase_lines(ts, (0,0,0.4), [[-10, 0]], interval=400, annotation=True)
#ax1 = neuron_model.visualise_phase_lines(ts, 'black', [[-50, 0]], interval=400, annotation=True)
ax1.plot([V_sol], [w_sol], marker='o', markerfacecolor='black', markeredgecolor='black',zorder=10,markersize=10)
ax1.plot([V_sol_unst], [w_sol_unst], marker='o', markerfacecolor='white', markeredgecolor='black',zorder=10,markersize=10)
ax1.set_title(f"V_0 = -10")

plt.show()
# Out:
# -68.64061889869545
# 0.00016193982656675932
# -43.24568234965487
# 0.02535403335266606
# ...

# %%
neuron_model.I_app = 20
neuron_model.I_spike = 20

V_sol = bifurcation_finder.steady_state_V(neuron_model.I_app, -80)
print(V_sol)
w_sol = neuron_model.w_inf(V_sol)
print(w_sol)

V_sol_unst = bifurcation_finder.steady_state_V(neuron_model.I_app, -40)
print(V_sol_unst)
w_sol_unst = neuron_model.w_inf(V_sol_unst)
print(w_sol_unst)

ax1, ax2 = neuron_model.visualise_phase_lines(ts, (0,0,0.4), [[-85, 0.0001]], interval=400, annotation=True, left_limit=-90)
#ax1 = neuron_model.visualise_phase_lines(ts, 'black', [[-50, 0]], interval=400, annotation=True)
ax1.plot([V_sol], [w_sol], marker='o', markerfacecolor='black', markeredgecolor='black',zorder=10,markersize=10)
ax1.plot([V_sol_unst], [w_sol_unst], marker='o', markerfacecolor='white', markeredgecolor='black',zorder=10,markersize=10)
ax1.set_title(f"V_0 = -85")

plt.show()
# Out:
# -68.64061889869545
# 0.00016193982656675932
# -43.24568234965487
# 0.02535403335266606
# ...
