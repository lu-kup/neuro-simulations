# %%
import neuron_model

print(neuron_model.model)
print(neuron_model.neuron)

import numpy as np
from scipy.integrate import solve_ivp
import bifurcation_finder
import matplotlib.pyplot as plt
# Out:
# LT
# ML

# %%
ts = np.linspace(0, neuron_model.T, 10**5)

# %%
neuron_model.I_app = 0
neuron_model.I_spike = 0

V_sol = bifurcation_finder.steady_state_V(neuron_model.I_app, -80)
print(V_sol)
w_sol = neuron_model.w_inf(V_sol)
print(w_sol)

ax1, ax2 = neuron_model.visualise_phase_lines(ts, (0,0,0.4), [[-40, -0.1],[-50, 0.5],[-20, 0.7],[-30, 0.4], [-120,0.8], [-120,0.3], [-120,-0.15], [-130,0]], interval=1000, annotation=False, left_limit=-140)
#ax1 = neuron_model.visualise_phase_lines(ts, 'black', [[-50, 0]], interval=400, annotation=True)
ax1.plot([V_sol], [w_sol], marker='o', markerfacecolor='white', markeredgecolor='black',zorder=10,markersize=10)
ax2.remove()
ax1.set_title(f"I_app = {neuron_model.I_app}")
plt.show()
# Out:
# -53.587778508247276
# 0.15218627269489332

# %%
neuron_model.I_app = -18.52735488
neuron_model.I_spike = -18.52735488

V_sol = bifurcation_finder.steady_state_V(neuron_model.I_app, -80)
print(V_sol)
w_sol = neuron_model.w_inf(V_sol)
print(w_sol)

ax1, ax2 = neuron_model.visualise_phase_lines(ts, (0,0,0.4), [[-40, -0.1],[-50, 0.5],[-20, 0.7],[-30, 0.4], [-120,0.8], [-120,0.3], [-120,-0.15], [-130,0]], interval=1000, annotation=False, left_limit=-140)
#ax1 = neuron_model.visualise_phase_lines(ts, 'black', [[-50, 0]], interval=400, annotation=True)
ax1.plot([V_sol], [w_sol], marker='o', markerfacecolor='white', markeredgecolor='black',zorder=10,markersize=10)
ax2.remove()
ax1.set_title(f"I_app = -18.5274")
plt.show()
# Out:
# -61.15803347724311
# 0.03799347878227283

# %%
neuron_model.I_app = -30
neuron_model.I_spike = -30
V_sol = bifurcation_finder.steady_state_V(neuron_model.I_app, -80)
print(V_sol)
w_sol = neuron_model.w_inf(V_sol)
print(w_sol)

ax1, ax2 = neuron_model.visualise_phase_lines(ts, (0,0,0.4), [[-40, -0.1],[-50, 0.5],[-20, 0.7],[-30, 0.4], [-120,0.8], [-120,0.3], [-120,-0.15], [-130,0]], interval=1000, annotation=True, left_limit=-140)
#ax1 = neuron_model.visualise_phase_lines(ts, 'black', [[-50, 0]], interval=400, annotation=True)
ax1.plot([V_sol], [w_sol], marker='o', markerfacecolor='black', markeredgecolor='black',zorder=10,markersize=10)
ax2.remove()
ax1.set_title(f"I_app = {neuron_model.I_app}")
plt.show()
# Out:
# -68.81314943680633
# 0.00847074587072022
# [1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000, 9000, 10000, 11000, 12000, 13000, 14000, 15000, 16000, 17000, 18000, 19000, 20000, 21000, 22000, 23000, 24000, 25000, 26000, 27000, 28000, 29000, 30000, 31000, 32000, 33000, 34000, 35000, 36000, 37000, 38000, 39000, 40000, 41000, 42000, 43000, 44000, 45000, 46000, 47000, 48000, 49000, 50000, 51000, 52000, 53000, 54000, 55000, 56000, 57000, 58000, 59000, 60000, 61000, 62000, 63000, 64000, 65000, 66000, 67000, 68000, 69000, 70000, 71000, 72000, 73000, 74000, 75000, 76000, 77000, 78000, 79000, 80000, 81000, 82000, 83000, 84000, 85000, 86000, 87000, 88000, 89000, 90000, 91000, 92000, 93000, 94000, 95000, 96000, 97000, 98000, 99000]
# ...

# %%
neuron_model.I_app = -20
neuron_model.I_spike = -20
V_sol = bifurcation_finder.steady_state_V(neuron_model.I_app, -80)
print(V_sol)
w_sol = neuron_model.w_inf(V_sol)
print(w_sol)

ax1, ax2 = neuron_model.visualise_phase_lines(ts, (0,0,0.4), [[-40, -0.1],[-50, 0.5],[-20, 0.7],[-30, 0.4], [-120,0.8], [-120,0.3], [-120,-0.15], [-130,0]], interval=1000, annotation=True, left_limit=-140)
#ax1 = neuron_model.visualise_phase_lines(ts, 'black', [[-50, 0]], interval=400, annotation=True)
ax1.plot([V_sol], [w_sol], marker='o', markerfacecolor='black', markeredgecolor='black',zorder=10,markersize=10)
ax2.remove()
ax1.set_title(f"I_app = {neuron_model.I_app}")
plt.show()
# Out:
# -62.49531037477767
# 0.029338929339708386
# [1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000, 9000, 10000, 11000, 12000, 13000, 14000, 15000, 16000, 17000, 18000, 19000, 20000, 21000, 22000, 23000, 24000, 25000, 26000, 27000, 28000, 29000, 30000, 31000, 32000, 33000, 34000, 35000, 36000, 37000, 38000, 39000, 40000, 41000, 42000, 43000, 44000, 45000, 46000, 47000, 48000, 49000, 50000, 51000, 52000, 53000, 54000, 55000, 56000, 57000, 58000, 59000, 60000, 61000, 62000, 63000, 64000, 65000, 66000, 67000, 68000, 69000, 70000, 71000, 72000, 73000, 74000, 75000, 76000, 77000, 78000, 79000, 80000, 81000, 82000, 83000, 84000, 85000, 86000, 87000, 88000, 89000, 90000, 91000, 92000, 93000, 94000, 95000, 96000, 97000, 98000, 99000]
# ...

# %% [markdown]
# SINGLE TRAJECTORIES

# %%
neuron_model.I_app = 0
neuron_model.I_spike = 0

V_sol = bifurcation_finder.steady_state_V(neuron_model.I_app, -80)
print(V_sol)
w_sol = neuron_model.w_inf(V_sol)
print(w_sol)

ax1, ax2 = neuron_model.visualise_phase_lines(ts, (0,0,0.4), [[-50, 0]], interval=1000, annotation=False, left_limit=-90)
#ax1 = neuron_model.visualise_phase_lines(ts, 'black', [[-50, 0]], interval=400, annotation=True)
ax1.plot([V_sol], [w_sol], marker='o', markerfacecolor='white', markeredgecolor='black',zorder=10,markersize=10)
ax1.set_title(f"I_app = {neuron_model.I_app}")
plt.show()
# Out:
# -53.587778508247276
# 0.15218627269489332

# %%
neuron_model.I_app = -18.52735488
neuron_model.I_spike = -18.52735488

V_sol = bifurcation_finder.steady_state_V(neuron_model.I_app, -80)
print(V_sol)
w_sol = neuron_model.w_inf(V_sol)
print(w_sol)

ax1, ax2 = neuron_model.visualise_phase_lines(ts, (0,0,0.4), [[-50, 0]], interval=1000, annotation=False, left_limit=-90)
#ax1 = neuron_model.visualise_phase_lines(ts, 'black', [[-50, 0]], interval=400, annotation=True)
ax1.plot([V_sol], [w_sol], marker='o', markerfacecolor='white', markeredgecolor='black',zorder=10,markersize=10)
ax1.set_title(f"I_app = -18.5274")
plt.show()
# Out:
# -61.15803347724311
# 0.03799347878227283

# %%
neuron_model.I_app = -30
neuron_model.I_spike = -30
V_sol = bifurcation_finder.steady_state_V(neuron_model.I_app, -80)
print(V_sol)
w_sol = neuron_model.w_inf(V_sol)
print(w_sol)

ax1, ax2 = neuron_model.visualise_phase_lines(ts, (0,0,0.4), [[-50, 0]], interval=400, annotation=True, left_limit=-90)
#ax1 = neuron_model.visualise_phase_lines(ts, 'black', [[-50, 0]], interval=400, annotation=True)
ax1.plot([V_sol], [w_sol], marker='o', markerfacecolor='black', markeredgecolor='black',zorder=10,markersize=10)
ax1.set_title(f"I_app = {neuron_model.I_app}")
plt.show()
# Out:
# -68.81314943680633
# 0.00847074587072022
# ...

# %%
neuron_model.I_app = -20
neuron_model.I_spike = -20
V_sol = bifurcation_finder.steady_state_V(neuron_model.I_app, -80)
print(V_sol)
w_sol = neuron_model.w_inf(V_sol)
print(w_sol)

ax1, ax2 = neuron_model.visualise_phase_lines(ts, (0,0,0.4), [[-50, 0]], interval=400, annotation=True, left_limit=-90)
#ax1 = neuron_model.visualise_phase_lines(ts, 'black', [[-50, 0]], interval=400, annotation=True)
ax1.plot([V_sol], [w_sol], marker='o', markerfacecolor='black', markeredgecolor='black',zorder=10,markersize=10)
ax1.set_title(f"I_app = {neuron_model.I_app}")
plt.show()
# Out:
# -62.49531037477767
# 0.029338929339708386
# ...
